# %% [markdown]
# #Website Traffic Analysis Project
#
# This project analyzes user interactions, traffic patterns, and engagement metrics using the provided dataset.

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-c45440a9-5350-4f26-9ed1-6cb94ec14019" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c45440a9-5350-4f26-9ed1-6cb94ec14019">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# #Upload datasets

# %%
import pandas as pd
df= pd.read_csv('task 3.csv')
df.head()
# Out:
#    event        date       country      city  \
# 0  click  21-08-2021  Saudi Arabia    Jeddah
# 1  click  21-08-2021  Saudi Arabia    Jeddah
# 2  click  21-08-2021         India  Ludhiana
# 3  click  21-08-2021        France   Unknown
# 4  click  21-08-2021      Maldives      Malé
#
#                               artist          album          track  \
# 0                             Tesher    Jalebi Baby    Jalebi Baby
# 1                             Tesher    Jalebi Baby    Jalebi Baby
# 2                      Reyanna Maria      So Pretty      So Pretty
# 3  Simone & Simaria, Sebastian Yatra  No Llores Más  No Llores Más
# 4                             Tesher    Jalebi Baby    Jalebi Baby
#
#            isrc                                linkid
# 0  QZNWQ2070741  2d896d31-97b6-4869-967b-1c5fb9cd4bb8
# 1  QZNWQ2070741  2d896d31-97b6-4869-967b-1c5fb9cd4bb8
# 2  USUM72100871  23199824-9cf5-4b98-942a-34965c3b0cc2
# 3  BRUM72003904  35573248-4e49-47c7-af80-08a960fa74cd
# ...

# %% [markdown]
# read csv (code)

# %%
print("Total Events:", len(df))
# Out:
# Total Events: 226278

# %%
df['country'].value_counts().head(10)
# Out:
# country
# Saudi Arabia            47334
# India                   42992
# United States           32558
# France                  15661
# Iraq                     8260
# United Kingdom           5970
# Pakistan                 5644
# Germany                  4794
# United Arab Emirates     3702
# Turkey                   3514
# Name: count, dtype: int64

# %%
df['city'].value_counts().head(10)
df['artist'].value_counts().head(10)
df['track'].value_counts().head(10)
# Out:
# track
# Jalebi Baby                              40841
# Beautiful                                10658
# Beautiful Day                             9751
# ily (i love you baby) (feat. Emilee)      7533
# So Pretty                                 5664
# Calabria (feat. Lujavo & Nito-Onna)       5512
# Summer of Love (Shawn Mendes & Tainy)     5409
# Candy Shop                                5375
# Late At Night                             5036
# Build a Bitch                             3879
# Name: count, dtype: int64

# %%
df['date']=pd.to_datetime(df['date'])

daily_events=df.groupby(df['date'].dt.date).size()
daily_events.plot(figsize=(10,5))
# Out:
# /tmp/ipykernel_2451/1431900242.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['date']=pd.to_datetime(df['date'])
# <Axes: xlabel='date'>

# %%
import matplotlib.pyplot as plt

top_artists = df['artist'].value_counts().head(10)

top_artists.plot(kind='bar')
plt.title('Top 10 Artists')
plt.xlabel('Artist')
plt.ylabel('Number of Events')
plt.show()

# %%
df['event'].value_counts()
# Out:
# event
# pageview    142015
# click        55732
# preview      28531
# Name: count, dtype: int64

# %%
pageviews = 142015
clicks = 55732

ctr = (clicks / pageviews) * 100

print("CTR =", round(ctr, 2), "%")
# Out:
# CTR = 39.24 %

# %%
df['country'].value_counts().head(10)
# Out:
# country
# Saudi Arabia            47334
# India                   42992
# United States           32558
# France                  15661
# Iraq                     8260
# United Kingdom           5970
# Pakistan                 5644
# Germany                  4794
# United Arab Emirates     3702
# Turkey                   3514
# Name: count, dtype: int64

# %%
event_counts = df['event'].value_counts()

plt.figure(figsize=(6,6))

plt.pie(
    event_counts,
    labels=event_counts.index,
    autopct='%1.1f%%'
)

plt.title('Event Distribution')
plt.show()

# %% [markdown]
# The dataset was checked for missing values and duplicate records. Duplicate records were removed to improve data quality.

# %%
df.isnull().sum()
# Out:
# event         0
# date          0
# country      11
# city         11
# artist       37
# album         5
# track         5
# isrc       7121
# linkid        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(103711)

# %%
df=df.drop_duplicates()

# %%
print(df.shape)
# Out:
# (122567, 9)

# %% [markdown]
# The distribution of user events such as pageviews, clicks, and previews was analyzed.

# %%
import matplotlib.pyplot as plt

df['event'].value_counts().plot(kind='bar')

plt.title('Event Distribution')
plt.xlabel('Event Type')
plt.ylabel('Count')
plt.show()

# %%
df['country'].value_counts().head(10).plot(kind='bar')

plt.title('Top 10 Countries')
plt.xlabel('Country')
plt.ylabel('Count')
plt.show()

# %%
df['artist'].value_counts().head(10).plot(kind='bar')

plt.title('Top 10 Artists')
plt.xlabel('Artist')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Traffic was analyzed across different countries and cities to identify key user locations.

# %%
import matplotlib.pyplot as plt

df['country'].value_counts().head(10).plot(kind='bar')

plt.title('Top 10 Countries')
plt.xlabel('Country')
plt.ylabel('Events')
plt.show()

# %%
df['city'].value_counts().head(10)
df['city'].value_counts().head(10).plot(kind='bar')

plt.title('Top 10 Cities')
plt.xlabel('City')
plt.ylabel('Events')
plt.show()

# %% [markdown]
# The most popular artists were identified based on user interactions

# %%
df['artist'].value_counts().head(10)
df['artist'].value_counts().head(10).plot(kind='bar')

plt.title('Top Artists')
plt.xlabel('Artist')
plt.ylabel('Events')
plt.show()

# %% [markdown]
# # Key Findings
#
# 1. The dataset contained 226,278 records before cleaning.
# 2. A significant number of duplicate records were identified and removed.
# 3. Pageview was the most common event, indicating strong user traffic.
# 4. Click events represented a substantial portion of user engagement.
# 5. User activity was concentrated in a limited number of countries and cities.
# 6. Certain artists received significantly higher interaction than others.

# %% [markdown]
# # Recommendations
#
# 1. Improve page content to increase the conversion of pageviews into clicks.
# 2. Focus marketing campaigns on the top-performing countries and cities.
# 3. Promote high-performing artists and tracks to maximize engagement.
# 4. Improve data quality by reducing missing metadata values.
# 5. Monitor user interaction trends regularly to identify growth opportunities.

# %% [markdown]
# # Conclusion
#
# The analysis provided insights into user interaction patterns, geographic distribution, and content popularity. After cleaning the dataset and analyzing event behavior, several opportunities were identified to improve engagement and optimize performance. The findings can support data-driven decision-making and marketing strategies.
